# %% [markdown]
# # Test Plant #
#
# Mostly to make sure everything is connected

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time

from aquaponics import Aquaponics
imode = 7

# %% [markdown]
# ## 1 bed 1 plant - no nitrogen ##

# %%
a = Aquaponics('plant', kswitch=100)
m = a.get_model()

tf = 45
steps = tf * 10 + 1
m.time = np.linspace(0,tf,steps)

a.solve(glamdring=True, imode=imode, disp=False)

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.plot(m.time, a.y, label='Yield')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 1 Bed 1 Plant - Nitrogen ##

# %%
a = Aquaponics('plant', N0=.1, kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 55.47 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.plot(m.time, a.y, label='Yield')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 1 Bed, 30 plants - Nitrogen ##

# %%
a = Aquaponics('plant', N0=.1, ppb0=30, kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 51.52 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.plot(m.time, a.y, label='Yield')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 1 Bed, 30 plants - Nitrogen - Staggered Start##

# %%
a = Aquaponics('plant', N0=.1, ppb0=30, beds=[(30, 60)], kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 101.71 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.plot(m.time, a.y, label='Yield')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 3 Beds, 30 plants - Nitrogen - Staggered Starts##

# %%
a = Aquaponics('plant', N0=.1, ppb0=30, beds=[(0,30), (30, 60), (60, 90)], kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 79.57 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.plot(m.time, a.y, label='Yield')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %%
m.options.IMODE = 9
a.ppb.STATUS = 1
m.options.COLD_START = 1
# a.ppb.DCOST = 1

m.solve()
print(a.ppb.value)
# Out:
# COLD_START is not a recognized property
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-a39d65262de3> in <module>()
#       1 m.options.IMODE = 9
#       2 a.ppb.STATUS = 1
# ----> 3 m.options.COLD_START = 1
#       4 # a.ppb.DCOST = 1
#       5
#
# ~\Envs\aquaponics\lib\site-packages\gekko-0.0.4b2-py3.5.egg\gekko\gk_global_options.py in __setattr__(self, name, value)
#     162             else:
#     163                 print(str(name)+" is not a recognized property")
# --> 164                 raise AttributeError
#     165
#     166         #for initializing model
#
# AttributeError:

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.plot(m.time, a.y, label='Yield')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')
