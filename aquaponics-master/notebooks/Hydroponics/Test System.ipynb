# %% [markdown]
# # Test Plant #
#
# Mostly to make sure everything is connected

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time

from aquaponics import Aquaponics
imode = 7

# %% [markdown]
# ## 1 bed 1 plant - no nitrogen ##

# %%
a = Aquaponics('plant', kswitch=100)
m = a.get_model()

tf = 45
steps = tf * 10 + 1
m.time = np.linspace(0,tf,steps)

a.solve(glamdring=True, imode=imode, disp=False)

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 1 Bed 1 Plant - Nitrogen ##

# %%
a = Aquaponics('plant', N0=.1, kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 11.92 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 1 Bed, 30 plants - Nitrogen ##

# %%
a = Aquaponics('plant', N0=.1, ppb0=30, kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 12.13 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 1 Bed, 30 plants - Nitrogen - Staggered Start##

# %%
a = Aquaponics('plant', N0=.1, ppb0=30, beds=[(30, 60)], kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 11.98 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## Test 3 Beds, 30 plants - Nitrogen - Staggered Starts##

# %%
a = Aquaponics('plant', N0=.1, ppb0=30, beds=[(0,30), (30, 60), (60, 90)], kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 12.51 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## 6 Beds - Overlapping Starts ##

# %%
a = Aquaponics('plant', N0=.1, ppb0=30, beds=[(0,30), (15, 45), (30, 60), (45, 75), (60, 90), (75, 90)], kswitch=100)
m = a.get_model()

tf = 90
steps = tf * 12 + 1
m.time = np.linspace(0,tf,steps)

start = time()
a.solve(glamdring=True, imode=imode, disp=False)
print('Solved in {:.2f} Seconds'.format(time() - start))
# Out:
# Solved in 18.31 Seconds

# %%
# %matplotlib inline
plt.figure(figsize=(12,6))
ax = plt.subplot(211)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

ax = plt.subplot(212, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')
