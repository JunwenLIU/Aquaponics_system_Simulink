# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time

from aquaponics import Aquaponics
imode = 9

# %% [markdown]
# ## 1 Plant - No Nitrogen ##

# %%
a = Aquaponics('hydroplant', kswitch=100)
m = a.get_model()

tf = 45
steps = tf * 10 + 1
m.time = np.linspace(0,tf,steps)

a.solve(glamdring=True, imode=imode, disp=False)

# %%
# %matplotlib inline
plt.figure(figsize=(12,9))
ax = plt.subplot(311)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

plt.subplot(312, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.subplot(313, sharex=ax)
plt.plot(m.time, a.cN, label='cN')
plt.grid()
plt.legend()


plt.xlim(0, tf)
plt.xlabel('Time (days)')
# Out:
# Text(0.5,0,'Time (days)')

# %% [markdown]
# ## 1 Plant - Nitrogen ##

# %%
a = Aquaponics('hydroplant', N0=0.1, kswitch=100)
m = a.get_model()

tf = 45
steps = tf * 10 + 1
m.time = np.linspace(0,tf,steps)

a.solve(glamdring=True, imode=imode, disp=True)
# Out:
# apmonitor 192.168.17.25_3837154992671 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 0.8.2
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            0
#    Variables    :           20
#    Intermediates:            8
#    Connections  :            0
#    Equations    :           13
#    Residuals    :            5
#
#  Number of state variables:           9000
#  Number of total equations: -         9000
#  Number of slack variables: -            0
#  ---------------------------------------
#  Degrees of freedom       :              0
#
#  Sequential solve ON but there are no degrees of freedom
#  Switching back to simultaneous solve
#  ----------------------------------------------
#  Sequential Control with APOPT Solver
#  ----------------------------------------------
#  Unknown option: linear_solver
#
#  Iter    Objective  Convergence
#     0  6.58671E+24  1.00000E+00
#     1     Infinity  9.95050E-01
#     2     Infinity  9.95045E-01
#     3     Infinity  9.95040E-01
#     4     Infinity  9.95035E-01
#     5     Infinity  9.95030E-01
#     6     Infinity  9.95025E-01
#     7     Infinity  9.95020E-01
#     8     Infinity  9.95016E-01
#     9     Infinity  9.95011E-01
#
#  Iter    Objective  Convergence
#    10     Infinity  9.95006E-01
#    11     Infinity  9.95001E-01
#    12     Infinity  9.94996E-01
#    13     Infinity  9.94991E-01
#    14     Infinity  9.94986E-01
#    15     Infinity  9.94981E-01
#    16     Infinity  9.94976E-01
#    17     Infinity  9.94986E-01
#    18     Infinity  9.94981E-01
#    19     Infinity  9.94976E-01
#
#  Iter    Objective  Convergence
#    20     Infinity  9.94971E-01
#    21     Infinity  9.94966E-01
#    22     Infinity  9.94961E-01
#    23     Infinity  9.94956E-01
#    24     Infinity  9.94966E-01
#    25     Infinity  9.94961E-01
#    26     Infinity  9.94956E-01
#    27     Infinity  9.94951E-01
#    28     Infinity  9.94947E-01
#    29     Infinity  9.94942E-01
#
#  Iter    Objective  Convergence
#    30     Infinity  9.94937E-01
#    31     Infinity  9.94947E-01
#    32     Infinity  9.94942E-01
#    33     Infinity  9.94937E-01
#    34     Infinity  9.94932E-01
#    35     Infinity  9.94927E-01
#    36     Infinity  9.94922E-01
#    37     Infinity  9.94917E-01
#    38     Infinity  9.94927E-01
#    39     Infinity  9.94922E-01
#
#  Iter    Objective  Convergence
#    40     Infinity  9.94917E-01
#    41     Infinity  9.94912E-01
#    42     Infinity  9.94907E-01
#    43     Infinity  9.94902E-01
#    44     Infinity  9.94897E-01
#    45     Infinity  9.94907E-01
#    46     Infinity  9.94902E-01
#    47     Infinity  9.94897E-01
#    48     Infinity  9.94892E-01
#    49     Infinity  9.94887E-01
#
#  Iter    Objective  Convergence
#    50     Infinity  9.94881E-01
#    51     Infinity  9.94876E-01
#    52     Infinity  9.94887E-01
#    53     Infinity  9.94881E-01
#    54     Infinity  9.94876E-01
#    55     Infinity  9.94870E-01
#    56     Infinity  9.94864E-01
#    57     Infinity  9.94858E-01
#    58     Infinity  9.94852E-01
#    59     Infinity  9.94864E-01
#
#  Iter    Objective  Convergence
#    60     Infinity  9.94858E-01
#    61     Infinity  9.94852E-01
#    62     Infinity  9.94845E-01
#    63     Infinity  9.94839E-01
#    64     Infinity  9.94832E-01
#    65     Infinity  9.94825E-01
#    66     Infinity  9.94818E-01
#    67     Infinity  9.94810E-01
#    68     Infinity  9.94803E-01
#    69     Infinity  9.94795E-01
#
#  Iter    Objective  Convergence
#    70     Infinity  9.94787E-01
#    71     Infinity  9.94779E-01
#    72     Infinity  9.94795E-01
#    73     Infinity  9.94787E-01
#    74     Infinity  9.94779E-01
#    75     Infinity  9.94770E-01
#    76     Infinity  9.94761E-01
#    77     Infinity  9.94752E-01
#    78     Infinity  9.94742E-01
#    79     Infinity  9.94761E-01
#
#  Iter    Objective  Convergence
#    80     Infinity  9.94752E-01
#    81     Infinity  9.94742E-01
#    82     Infinity  9.94732E-01
#    83     Infinity  9.94722E-01
#    84     Infinity  9.94711E-01
#    85     Infinity  9.94700E-01
#    86     Infinity  9.94722E-01
#    87     Infinity  9.94711E-01
#    88     Infinity  9.94700E-01
#    89     Infinity  9.94689E-01
#
#  Iter    Objective  Convergence
#    90     Infinity  9.94676E-01
#    91     Infinity  9.94664E-01
#    92     Infinity  9.94650E-01
#    93     Infinity  9.94636E-01
#    94     Infinity  9.94622E-01
#    95     Infinity  9.94606E-01
#    96     Infinity  9.94636E-01
#    97     Infinity  9.94622E-01
#    98     Infinity  9.94606E-01
#    99     Infinity  9.94589E-01
#
#  Iter    Objective  Convergence
#   100     Infinity  9.94572E-01
#   101     Infinity  9.94553E-01
#   102     Infinity  9.94589E-01
#   103     Infinity  9.94572E-01
#   104     Infinity  9.94553E-01
#   105  1.29835+292  9.94534E-01
#   106  1.69017+268  9.94513E-01
Infinity  2.16101E+10
#
#  Iter    Objective  Convergence
#   190     Infinity  8.23027E+11
#   191     Infinity  2.16101E+10
#   192     Infinity  8.23027E+11
#   193     Infinity  2.16101E+10
#   194     Infinity  8.23027E+11
#   195     Infinity  2.16101E+10
#   196     Infinity  8.23027E+11
#   197     Infinity  2.16101E+10
#   198     Infinity  8.23027E+11
#   199     Infinity  2.16101E+10
#
#  Iter    Objective  Convergence
#   200     Infinity  8.23027E+11
#   201     Infinity  2.16101E+10
#   202     Infinity  8.23027E+11
#   203     Infinity  2.16101E+10
#   204     Infinity  8.23027E+11
#   205     Infinity  2.16101E+10
#   206     Infinity  8.23027E+11
#   207     Infinity  2.16101E+10
#   208     Infinity  8.23027E+11
#   209     Infinity  2.16101E+10
#
#  Iter    Objective  Convergence
#   210     Infinity  8.23027E+11
#   211     Infinity  2.16101E+10
#   212     Infinity  8.23027E+11
#   213     Infinity  2.16101E+10
#   214     Infinity  8.23027E+11
#   215     Infinity  2.16101E+10
#   216     Infinity  8.23027E+11
#   217     Infinity  2.16101E+10
#   218     Infinity  8.23027E+11
#   219     Infinity  2.16101E+10
#
#  Iter    Objective  Convergence
#   220     Infinity  8.23027E+11
#   221     Infinity  2.16101E+10
#   222     Infinity  8.23027E+11
#   223     Infinity  2.16101E+10
#   224     Infinity  8.23027E+11
#   225     Infinity  2.16101E+10
#   226     Infinity  8.23027E+11
#   227     Infinity  2.16101E+10
#   228     Infinity  8.23027E+11
#   229     Infinity  2.16101E+10
#
#  Iter    Objective  Convergence
#   230     Infinity  8.23027E+11
#   231     Infinity  2.16101E+10
#   232     Infinity  8.23027E+11
#   233     Infinity  2.16101E+10
#   234     Infinity  8.23027E+11
#   235     Infinity  2.16101E+10
#   236     Infinity  8.23027E+11
#   237     Infinity  2.16101E+10
#   238     Infinity  8.23027E+11
#   239     Infinity  2.16101E+10
#
#  Iter    Objective  Convergence
#   240     Infinity  8.23027E+11
#   241     Infinity  2.16101E+10
#   242     Infinity  8.23027E+11
#   243     Infinity  2.16101E+10
#   244     Infinity  8.23027E+11
#   245     Infinity  2.16101E+10
#   246     Infinity  8.23027E+11
#   247     Infinity  2.16101E+10
#   248     Infinity  8.23027E+11
#   249     Infinity  2.16101E+10
#
#  Iter    Objective  Convergence
#   250     Infinity  8.23027E+11
#  Maximum iterations
#
#  ---------------------------------------------------
#  Solver         :  APOPT (v1.0)
#  Solution time  :    614.676399999997      sec
#  Objective      :   0.000000000000000E+000
#  Unsuccessful with error code            0
#  ---------------------------------------------------
#
#  Creating file: infeasibilities.txt
#  Use command apm_get(server,app,'infeasibilities.txt') to retrieve file
# </pre>

# %%
# %matplotlib inline
plt.figure(figsize=(12,9))
ax = plt.subplot(311)
plt.plot(m.time, a.w, label='Dry Weight')
plt.grid()
plt.legend()

plt.subplot(312, sharex=ax)
plt.plot(m.time, a.dNup, label='dNup')
plt.grid()
plt.legend()

plt.subplot(313, sharex=ax)
plt.plot(m.time, a.cN, label='cN')
plt.grid()
plt.legend()


plt.xlim(0, tf)
plt.xlabel('Time (days)')
